# %%
! pip3 install turtle
import turtle
pen = turtle.Turtle
turtle.forward(180)
turtle.left(120)
turtle.forward(180)
turtle.left(120)
turtle.forward(180)
turtle.fillcolor ("red")
turtle.begin_fill()
turtle.penup()
turtle.left(30)
turtle.pendown()
turtle.forward(250)
turtle.left(90)
turtle.forward(60)
turtle.left(90)
turtle.forward(80)
turtle.right(90)
turtle.forward(60)
turtle.right(90)
turtle.forward(80)
turtle.left(90)
turtle.forward(60)
turtle.left(90)
turtle.forward(250)
turtle.fillcolor ("blue")
turtle.begin_fill()
turtle.penup()
turtle.right(45)
turtle.pendown()
turtle.forward(250)
turtle.right(135)
turtle.forward(250)
turtle.right(45)
turtle.forward(250)
turtle.backward(250)
turtle.right(135)
turtle.forward(250)
turtle.penup()
turtle.left(30)
turtle.pendown()
turtle.forward(180)
turtle.penup()
turtle.left(105)
turtle.pendown()
turtle.forward(250)
turtle.penup()
turtle.right(45)
turtle.forward(350)
turtle.pendown()
turtle.left(60)
turtle.forward(100)
turtle.left(120)
turtle.forward(100)
turtle.left(120)
turtle.forward(100)
turtle.backward(100)
turtle.left(60)
turtle.forward(50)
turtle.left(60)
turtle.forward(100)
turtle.left(120)
turtle.forward(100)
turtle.left(120)
turtle.forward(100)
turtle.backward(100)
turtle.left(60)
turtle.forward(50)
turtle.left(60)
turtle.forward(100)
turtle.left(120)
turtle.forward(100)
turtle.left(120)
turtle.forward(100)
turtle.backward(100)
turtle.left(60)
turtle.forward(60)
turtle.left(90)
turtle.forward(100)
turtle.left(90)
turtle.forward(20)
turtle.left(90)
turtle.forward(100)
turtle.done()
